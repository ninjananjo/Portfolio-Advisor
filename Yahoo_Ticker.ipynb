# %%
# !pip install Yahoo-ticker-downloader
# !pip install pandas

import pandas as pd
import numpy as np
import YahooTickerDownloader
# Out:
# Requirement already satisfied: Yahoo-ticker-downloader in c:\users\james\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: requests>=2.4.3 in c:\users\james\anaconda3\lib\site-packages (from Yahoo-ticker-downloader) (2.19.1)
# Requirement already satisfied: tablib>=0.9.11 in c:\users\james\anaconda3\lib\site-packages (from Yahoo-ticker-downloader) (0.13.0)
# Requirement already satisfied: backports.csv>=1.0.4 in c:\users\james\anaconda3\lib\site-packages (from Yahoo-ticker-downloader) (1.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\james\anaconda3\lib\site-packages (from requests>=2.4.3->Yahoo-ticker-downloader) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\james\anaconda3\lib\site-packages (from requests>=2.4.3->Yahoo-ticker-downloader) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\james\anaconda3\lib\site-packages (from requests>=2.4.3->Yahoo-ticker-downloader) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\james\anaconda3\lib\site-packages (from requests>=2.4.3->Yahoo-ticker-downloader) (2.7)
# Requirement already satisfied: xlwt in c:\users\james\anaconda3\lib\site-packages (from tablib>=0.9.11->Yahoo-ticker-downloader) (1.3.0)
# Requirement already satisfied: odfpy in c:\users\james\anaconda3\lib\site-packages (from tablib>=0.9.11->Yahoo-ticker-downloader) (1.4.0)
# Requirement already satisfied: openpyxl>=2.4.0 in c:\users\james\anaconda3\lib\site-packages (from tablib>=0.9.11->Yahoo-ticker-downloader) (2.6.1)
# Requirement already satisfied: pyyaml in c:\users\james\anaconda3\lib\site-packages (from tablib>=0.9.11->Yahoo-ticker-downloader) (5.1)
# Requirement already satisfied: xlrd in c:\users\james\anaconda3\lib\site-packages (from tablib>=0.9.11->Yahoo-ticker-downloader) (1.2.0)
# Requirement already satisfied: defusedxml in c:\users\james\anaconda3\lib\site-packages (from odfpy->tablib>=0.9.11->Yahoo-ticker-downloader) (0.5.0)
# Requirement already satisfied: jdcal in c:\users\james\anaconda3\lib\site-packages (from openpyxl>=2.4.0->tablib>=0.9.11->Yahoo-ticker-downloader) (1.4)
# Requirement already satisfied: et-xmlfile in c:\users\james\anaconda3\lib\site-packages (from openpyxl>=2.4.0->tablib>=0.9.11->Yahoo-ticker-downloader) (1.0.1)
# Requirement already satisfied: pandas in c:\users\james\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\james\anaconda3\lib\site-packages (from pandas) (1.16.2)
# Requirement already satisfied: pytz>=2011k in c:\users\james\anaconda3\lib\site-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\james\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\james\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-97d0b877c2ca> in <module>
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 import YahooTickerDownloader
#
# ModuleNotFoundError: No module named 'YahooTickerDownloader'

# %%
YahooTickerDownloader.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b0572139555d> in <module>
# ----> 1 YahooTickerDownloader.py
#
# NameError: name 'YahooTickerDownloader' is not defined

# %%
weblink = 'https://www.nasdaq.com/screening/companies-by-name.aspx?letter=A&render=download'
sym_df = pd.read_csv(weblink)
stock_symbol_list = sym_df.Symbol.tolist()

# %%
stock_symbol_list
# Out:
# ['YI',
#  'PIH',
#  'PIHPP',
#  'TURN',
#  'FLWS',
#  'BCOW',
#  'FCCY',
#  'SRCE',
#  'VNET',
#  'XXII',
#  'TWOU',
#  'QFIN',
#  'DDD',
#  'MMM',
#  'WBAI',
#  'JOBS',
#  'WUBA',
#  'JFK',
#  'JFKKR',
#  'JFKKU',
#  'JFKKW',
#  'EGHT',
#  'AHC',
#  'AOS',
#  'ATEN',
#  'AAC',
#  'AAON',
#  'AIR',
#  'AAN',
#  'ABB',
#  'ABT',
#  'ABBV',
#  'ABEO',
#  'ABEOW',
#  'ANF',
#  'FAX',
#  'IAF',
#  'AEF',
#  'AGD',
#  'FCO',
#  'AWP',
#  'ACP',
#  'JEQ',
#  'AOD',
#  'ABIL',
#  'ABMD',
#  'ABM',
#  'AXAS',
#  'ACIU',
#  'ACIA',
#  'ACTG',
#  'ACHC',
#  'ACAD',
#  'AKR',
#  'ACAM',
#  'ACAMU',
#  'ACAMW',
#  'ACST',
#  'AXDX',
#  'ACCP',
#  'XLRN',
#  'ACN',
#  'ACCO',
#  'ARAY',
#  'ACRX',
#  'ACER',
#  'ACHV',
#  'ACHN',
#  'ACIW',
#  'ACRS',
#  'ACMR',
#  'ACU',
#  'ACNB',
#  'ACOR',
#  'ATV',
#  'ACTT',
#  'ACTTU',
#  'ACTTW',
#  'ATNM',
#  'ATVI',
#  'ATU',
#  'AYI',
#  'GOLF',
#  'ADMS',
#  'ADMP',
#  'ADX',
#  'PEO',
#  'AE',
#  'ADAP',
#  'ADUS',
#  'AEY',
#  'AGRO',
#  'IOTS',
#  'ADIL',
#  'ADILW',
#  'ADNT',
#  'ADMA',
#  'ADBE',
#  'ADOM',
#  'ADT',
#  'ATGE',
#  'ADTN',
#  'ADRO',
#  'AAP',
#  'ADSW',
#  'WMS',
#  'ADES',
#  'AEIS',
#  'AMD',
#  'ASIX',
#  'ADXS',
#  'AVK',
#  'ADVM',
#  'DWMC',
#  'DWSH',
#  'BKCH',
#  'ACT',
#  'ADYX',
#  'ACM',
#  'AEGN',
#  'AGLE',
#  'AEB',
#  'AED.CL',
#  'AEG',
#  'AEH',
#  'AEHR',
#  'AMTX',
#  'AER',
#  'AERI',
#  'ACY',
#  'HIVE',
#  'AJRD',
#  'AVAV',
#  'ARPO',
#  'AEZS',
#  'AEMD',
#  'GNMX',
#  'AMG',
#  'MGR',
#  'AFMD',
#  'AFL',
#  'MITT',
#  'MITT^A',
#  'MITT^B',
#  'AGBAU',
#  'AGCO',
#  'UAVS',
#  'AGEN',
#  'AGE',
#  'AGRX',
#  'A',
#  'AGYS',
#  'AGIO',
#  'AGMH',
#  'AGNC',
#  'AGNCB',
#  'AGNCM',
#  'AGNCN',
#  'AEM',
#  'ADC',
#  'AGFS',
#  'AGFSW',
#  'ALRN',
#  'AIMT',
#  'AIRI',
#  'AL',
#  'AL^A',
#  'APD',
#  'AIRT',
#  'ATSG',
#  'AYR',
#  'AIRG',
#  'AMCN',
#  'AITB',
#  'AKS',
#  'AKAM',
#  'AKTX',
#  'AKCA',
#  'AKBA',
#  'AKER',
#  'AKRX',
#  'AKTS',
#  'ALP^Q',
#  'ALG',
#  'AGI',
#  'ALRM',
#  'ALK',
#  'ALSK',
#  'AIN',
#  'ALB',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALACW',
#  'ALBO',
#  'ABDC',
#  'AA',
#  'ALC',
#  'ALDR',
#  'ALDX',
#  'ALEC',
#  'ALEX',
#  'ALX',
#  'ARE',
#  'ARE^D',
#  'AXU',
#  'ALXN',
#  'AQN',
#  'AQNA',
#  'BABA',
#  'ALCO',
#  'ALIT',
#  'ALGN',
#  'ALIM',
#  'ALO',
#  'ALYA',
#  'ALJJ',
#  'ALKS',
#  'ALLK',
#  'Y',
#  'ATI',
#  'ABTX',
#  'ALGT',
#  'ALLE',
#  'ALGR',
#  'ALGRR',
#  'ALGRU',
#  'ALGRW',
#  'ALNA',
#  'AGN',
#  'ALE',
#  'ADS',
#  'AFB',
#  'ARLP',
#  'AWF',
#  'AB',
#  'LNT',
#  'CBH',
#  'NCV',
#  'NCV^A',
#  'NCZ',
#  'NCZ^A',
#  'ACV',
#  'NIE',
#  'NFJ',
#  'AHPI',
#  'AMOT',
#  'ALSN',
#  'ALLO',
#  'ALLT',
#  'MDRX',
#  'ALL',
#  'ALL^A',
#  'ALL^B',
#  'ALL^D',
#  'ALL^E',
#  'ALL^F',
#  'ALL^G',
#  'ALLY',
#  'ALLY^A',
#  'AAU',
#  'ALNY',
#  'AOSL',
#  'APT',
#  'GOOG',
#  'GOOGL',
#  'SMCP',
#  'ATEC',
#  'ALPN',
#  'AMR',
#  'AMRWW',
#  'AABA',
#  'ALTR',
#  'ATHE',
#  'AYX',
#  'ATUS',
#  'ALT',
#  'AAMC',
#  'ASPS',
#  'AIMC',
#  'MO',
#  'ALTM',
#  'ACH',
#  'AMAG',
#  'AMAL',
#  'AMRN',
#  'AMRK',
#  'AMZN',
#  'AMBC',
#  'AMBCW',
#  'AMBA',
#  'AMBR',
#  'ABEV',
#  'AMBO',
#  'AMC',
#  'AMCX',
#  'AMCI',
#  'AMCIU',
#  'AMCIW',
#  'DIT',
#  'DOX',
#  'AMED',
#  'UHAL',
#  'AEE',
#  'AMRC',
#  'AMRH',
#  'AMRHW',
#  'ATAX',
#  'AMOV',
#  'AMX',
#  'AAL',
#  'AAT',
#  'AXL',
#  'ACC',
#  'AEO',
#  'AEP',
#  'AEP^B',
#  'AETI',
#  'AEL',
#  'AXP',
#  'AFIN',
#  'AFINP',
#  'AFG',
#  'AFGB',
#  'AFGE',
#  'AFGH',
#  'AMH',
#  'AMH^D',
#  'AMH^E',
#  'AMH^F',
#  'AMH^G',
#  'AMH^H',
#  'AIG',
#  'AIG.WS',
#  'AIG^A',
#  'AMID',
#  'AMNB',
#  'ANAT',
#  'AOBC',
#  'APEI',
#  'ARL',
#  'ARA',
#  'AREC',
#  'AMRB',
#  'AMS',
#  'AMSWA',
#  'AWR',
#  'AMSC',
#  'AMT',
#  'AVD',
#  'AWK',
#  'AMWD',
#  'CRMT',
#  'USAS',
#  'COLD',
#  'APU',
#  'AMP',
#  'ABCB',
#  'AMSF',
#  'ASRV',
#  'ASRVP',
#  'ABC',
#  'ATLO',
#  'AMGN',
#  'FOLD',
#  'ANFI',
#  'AMKR',
#  'AMN',
#  'AMRX',
#  'AP',
#  'AMPH',
#  'APH',
#  'AMPE',
#  'IBUY',
#  'AXR',
#  'ASYS',
#  'AME',
#  'AMRS',
#  'APC',
#  'ADI',
#  'PLAN',
#  'ANAB',
#  'AVXL',
#  'ANCN',
#  'ANDX',
#  'ANDA',
#  'ANDAR',
#  'ANDAU',
#  'ANDAW',
#  'ANGI',
#  'ANGO',
#  'AU',
#  'BUD',
#  'ANIP',
#  'ANIK',
#  'ANIX',
#  'AXE',
#  'NLY',
#  'NLY^C',
#  'NLY^D',
#  'NLY^F',
#  'NLY^G',
#  'NLY^H.CL',
#  'ANSS',
#  'ATRS',
#  'AM',
#  'AR',
#  'ANTM',
#  'ANH',
#  'ANH^A',
#  'ANH^B',
#  'ANH^C',
#  'AON',
#  'APA',
#  'AIV',
#  'APLS',
#  'APY',
#  'APHA',
#  'APOG',
#  'ARI',
#  'ARI^C.CL',
#  'APEN',
#  'APO',
#  'APO^A',
#  'APO^B',
#  'AINV',
#  'AIY',
#  'AMEH',
#  'AFT',
#  'AIF',
#  'APPF',
#  'APPN',
#  'APLE',
#  'AAPL',
#  'ARCI',
#  'APDN',
#  'APDNW',
#  'AGTC',
#  'AIT',
#  'AMAT',
#  'AAOI',
#  'APLT',
#  'AREX',
#  'ATR',
#  'APVO',
#  'APTX',
#  'APTV',
#  'APM',
#  'APTO',
#  'APYX',
#  'WTR',
#  'WTRU',
#  'AQMS',
#  'AQB',
#  'AQ',
#  'WAAS',
#  'AQST',
#  'AQXP',
#  'ARMK',
#  'PETX',
#  'ARAV',
#  'ABR',
#  'ABR^A',
#  'ABR^B',
#  'ABR^C',
#  'ABUS',
#  'ARC',
#  'ARCW',
#  'ABIO',
#  'RKDA',
#  'ARCB',
#  'MT',
#  'ACGL',
#  'ACGLO',
#  'ACGLP',
#  'ARCH',
#  'ADM',
#  'AROC',
#  'FUV',
#  'ARCE',
#  'ARNC^',
#  'ARNC',
#  'ARCO',
#  'ACA',
#  'ARCT',
#  'RCUS',
#  'ARD',
#  'ARDX',
#  'ASC',
#  'ARNA',
#  'AFC',
#  'ARCC',
#  'ACRE',
#  'ARDC',
#  'ARES',
#  'ARES^A',
#  'AGX',
#  'ARGX',
#  'ARGD',
#  'ARGO',
#  'ARDS',
#  'ANET',
#  'ARKR',
#  'AI',
#  'AI^B',
#  'AI^C',
#  'AIC',
#  'AIW',
#  'ARLO',
#  'AHH',
#  'ARMP',
#  'ARR',
#  'ARR^A',
#  'ARR^B',
#  'AFI',
#  'AWI',
#  'ARTX',
#  'ARQL',
#  'ARRY',
#  'DWCR',
#  'DWAT',
#  'ARW',
#  'AROW',
#  'ARWR',
#  'ARTNA',
#  'AJG',
#  'APAM',
#  'ARTW',
#  'ARVN',
#  'ARYA',
#  'ARYAU',
#  'ARYAW',
#  'ASA',
#  'AKG',
#  'ABG',
#  'ASNA',
#  'ASND',
#  'ASCMA',
#  'ASX',
#  'ASGN',
#  'AHT',
#  'AHT^D',
#  'AHT^F',
#  'AHT^G',
#  'AHT^H',
#  'AHT^I',
#  'AINC',
#  'ASH',
#  'APWC',
#  'ASLN',
#  'ASML',
#  'ASPN',
#  'ASPU',
#  'AHL^C',
#  'AHL^D',
#  'AZPN',
#  'ASMB',
#  'ASRT',
#  'ASB',
#  'ASB^C',
#  'ASB^D',
#  'ASB^E',
#  'AC',
#  'AIZ',
#  'AIZP',
#  'AGO',
#  'AGO^B',
#  'AGO^E',
#  'AGO^F',
#  'ASFI',
#  'ASTE',
#  'AZN',
#  'ATRO',
#  'ALOT',
#  'ASTC',
#  'ASUR',
#  'ASV',
#  'HOME',
#  'T',
#  'TBB',
#  'TBC',
#  'ATAI',
#  'ATRA',
#  'ATTO',
#  'ATH',
#  'ATNX',
#  'ATHX',
#  'ATIF',
#  'ATKR',
#  'AAME',
#  'ACBI',
#  'AT',
#  'AY',
#  'ATLC',
#  'AAWW',
#  'AFH',
#  'AFHBL',
#  'TEAM',
#  'ATO',
#  'ATNI',
#  'ATOM',
#  'ATOS',
#  'ATRC',
#  'ATRI',
#  'ATIS',
#  'ATISW',
#  'LIFE',
#  'AUO',
#  'AUBN',
#  'BOLD',
#  'AUDC',
#  'AEYE',
#  'AUPH',
#  'EARS',
#  'ACB',
#  'JG',
#  'AUG',
#  'ADSK',
#  'ATHM',
#  'ALV',
#  'AUTL',
#  'ADP',
#  'AN',
#  'AUTO',
#  'AZO',
#  'AVDL',
#  'AVLR',
#  'AVCO',
#  'AWX',
#  'AVB',
#  'AGR',
#  'AVNS',
#  'AVYA',
#  'AVDR',
#  'ATXI',
#  'AVEO',
#  'AVY',
#  'AVH',
#  'AVNW',
#  'CDMO',
#  'CDMOP',
#  'AVID',
#  'AVGR',
#  'ASM',
#  'CAR',
#  'AVA',
#  'AVT',
#  'AVP',
#  'AVRO',
#  'AVX',
#  'AWRE',
#  'EQH',
#  'AXTA',
#  'ACLS',
#  'AXLA',
#  'AXS',
#  'AXS^D',
#  'AXS^E',
#  'AXGN',
#  'AAXN',
#  'AXNX',
#  'AX',
#  'AXO',
#  'AXGT',
#  'AXSM',
#  'AXTI',
#  'AYTU',
#  'AZUL',
#  'AZRE',
#  'AZRX',
#  'AZZ']

# %%
#!/usr/bin/env python

import pickle
from time import sleep
import argparse
import io

from ytd import SimpleSymbolDownloader
from ytd.downloader.GenericDownloader import GenericDownloader
from ytd.compat import text
from ytd.compat import csv
from ytd.compat import robotparser

import tablib

import sys

user_agent = SimpleSymbolDownloader.user_agent

options = {
    "generic": GenericDownloader()
}


def loadDownloader(tickerType):
    with open(tickerType + ".pickle", "rb") as f:
        return pickle.load(f)


def saveDownloader(downloader, tickerType):
    with open(tickerType + ".pickle", "wb") as f:
        pickle.dump(downloader, file=f, protocol=pickle.HIGHEST_PROTOCOL)


def downloadEverything(downloader, tickerType, insecure, sleeptime, pandantic):

    loop = 0
    while not downloader.isDone():

        symbols = downloader.nextRequest(insecure, pandantic)
        print("Got " + str(len(symbols)) + " downloaded " + downloader.type + " symbols:")
        if(len(symbols) > 2):
            try:
                print (" " + text(symbols[0]))
                print (" " + text(symbols[1]))
                print ("  ect...")
            except:
                print (" Could not display some ticker symbols due to char encoding")
        downloader.printProgress()

        # Save download state occasionally.
        # We do this in case this long running is suddenly interrupted.
        loop = loop + 1
        if loop % 200 == 0:
            print ("Saving downloader to disk...")
            saveDownloader(downloader, tickerType)
            print ("Downloader successfully saved.")
            print ("")

        if not downloader.isDone():
            sleep(sleeptime)  # So we don't overload the server.

def main():
    downloader = None

    parser = argparse.ArgumentParser()
    parser.add_argument("-i", "--insecure", help="use HTTP instead of HTTPS", action="store_true")
    parser.add_argument("-e", "--export", help="export immediately without downloading (Only useful if you already downloaded something to the .pickle file)", action="store_true")
    parser.add_argument('-E', '--Exchange', help='Only export ticker symbols from this exchange (the filtering is done during the export phase)')
    parser.add_argument('type', nargs='?', default='generic', help='The type to download, this can be: '+" ".join(list(options.keys())))
    parser.add_argument("-s", "--sleep", help="The time to sleep in seconds between requests", type=float, default=0)
    parser.add_argument("-p", "--pandantic", help="Stop and warn the user if some rare assertion fails", action="store_true")

    args = parser.parse_args()

    protocol = 'http' if args.insecure else 'https'
    if args.insecure:
        print("Using insecure connection")

    if args.export:
        print("Exporting pickle file")

    tickerType = args.type = args.type.lower()

    print("Checking if we can resume a old download session")
    try:
        downloader = loadDownloader(tickerType)
        print("Downloader found on disk, resuming")
    except:
        print("No old downloader found on disk")
        print("Starting a new session")
        if tickerType not in options:
            print("Error: " + tickerType + " is not a valid type option. See --help")
            exit(1)
        else:
            downloader = options[tickerType]

    rp = robotparser.RobotFileParser()
    rp.set_url(protocol + '://finance.yahoo.com/robots.txt')
    rp.read()
    try:
        if not args.export:
            
            if(not rp.can_fetch(user_agent, protocol + '://finance.yahoo.com/_finance_doubledown/api/resource/searchassist')):
                print('Execution of script halted due to robots.txt')
                return 1
            
            if not downloader.isDone():
                print("Downloading " + downloader.type)
                print("")
                downloadEverything(downloader, tickerType, args.insecure, args.sleep, args.pandantic)
                print ("Saving downloader to disk...")
                saveDownloader(downloader, tickerType)
                print ("Downloader successfully saved.")
                print ("")
            else:
                print("The downloader has already finished downloading everything")
                print("")

    except Exception as ex:
        print("A exception occurred while downloading. Suspending downloader to disk")
        saveDownloader(downloader, tickerType)
        print("Successfully saved download state")
        print("Try removing {type}.pickle file if this error persists")
        print("Issues can be reported on https://github.com/Benny-/Yahoo-ticker-symbol-downloader/issues")
        print("")
        raise
    except KeyboardInterrupt as ex:
        print("Suspending downloader to disk as .pickle file")
        saveDownloader(downloader, tickerType)

    if downloader.isDone() or args.export:
        print("Exporting "+downloader.type+" symbols")

        data = tablib.Dataset()
        data.headers = downloader.getRowHeader()

        for symbol in downloader.getCollectedSymbols():
            if(args.Exchange == None):
                data.append(symbol.getRow())
            elif (symbol.exchange == args.Exchange):
                data.append(symbol.getRow())

        with io.open(downloader.type + '.csv', 'w', encoding='utf-8') as f:
            f.write(text.join(u',', data.headers) + '\n')
            writer = csv.writer(f)
            for i in range(0, len(data)):
                row = [text(y) if not y is None else u"" for y in data[i]]
                writer.writerow(row)

        try:
            with open(downloader.type + '.xlsx', 'wb') as f:
                f.write(data.xlsx)
        except:
            print("Could not export .xlsx due to a internal error")

        try:
            with open(downloader.type + '.json', 'wb') as f:
                f.write(data.json.encode('UTF-8'))
        except:
            print("Could not export .json due to a internal error")

        try:
            with open(downloader.type + '.yaml', 'wb') as f:
                f.write(data.yaml.encode('UTF-8'))
        except:
            print("Could not export .yaml due to a internal error")

if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [-i] [-e] [-E EXCHANGE] [-s SLEEP] [-p]
#                              [type]
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
